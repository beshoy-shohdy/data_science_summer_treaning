# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import movie_project as mp

# %%
mp.file_ready()
# Out:
# file is ready

# %%
df = pd.read_csv('merged_movie_data.csv')

# %%
plt.figure(figsize=(24, 10))
plt.bar(df['genre'], df['revenue'])
plt.title('Revenue by Genre')
plt.xlabel('Genre')
plt.ylabel('Revenue')
plt.show()
